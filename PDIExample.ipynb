# %% [markdown]
# ## Lectura de una imagen almacenada, despligue de la imagen y escriba a disco la imagen guardada

# %%
pip install opencv-python

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Ruta de la imagen
image_path = "/content/cat.jpg"

# %%
# Leer la imagen
image = cv2.imread(image_path, 0)
print(image)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
# Verificar si la imagen se leyó correctamente
if image is None:
    print("No se pudo cargar la imagen")
else:
    print(f"Imagen cargada exitosamente. Dimensiones: {image.shape}")
# Out:
# Imagen cargada exitosamente. Dimensiones: (612, 612)

# %%
# Mostrar la imagen en una ventana
cv2_imshow(image)

# Esperar a que el usuario cierre la ventana
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=612x612>

# %%
# Ruta para guardar la nueva imagen
output_path = "/content/salida.jpg"

# Guardar la imagen
success = cv2.imwrite(output_path, image)

if success:
    print(f"Imagen guardada exitosamente en {output_path}")
else:
    print("No se pudo guardar la imagen")
# Out:
# Imagen guardada exitosamente en /content/salida.jpg
